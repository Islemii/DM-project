# %% [markdown]
# # <center>Projet Data Mining: <font color=green>Analyse de la richesse mondiale : Évolution des milliardaires de💰 1997 à 2023 💰

# %% [markdown]
# ### <center>Elaborér par:<font color=blue> Islem Ben Hassouna - 2BD2

# %% [markdown]
# # **<font color=red>1)Introduction:💰 objectif de l'analyse**

# %% [markdown]
# Mon analyse du dataset "Forbes Billionaires Evolution (1997-2023)" a plusieurs<font color=green> objectifs :
#
# <font color=red>**1.**<font color=green>Comprendre les tendances temporelles :<font color=noir> Analyser comment la richesse des milliardaires a évolué au fil du temps, identifier les années où il y a eu des changements significatifs, et comprendre les facteurs économiques ou sociaux qui ont pu influencer ces tendances.
#
# <font color=red>**2.**<font color=green>Analyser la répartition de la richesse :<font color=noir> Examiner la distribution de la richesse parmi les milliardaires au fil des années, identifier les régions géographiques où se concentre la majorité de la richesse, et comprendre les facteurs démographiques ou géopolitiques qui pourraient expliquer ces différences.
#
# <font color=red>**3.**<font color=green>Disparités de genre parmi les plus riches du monde
#
# <font color=red>**4.**<font color=green>Étudier les caractéristiques des milliardaires :<font color=noir> Analyser les caractéristiques démographiques <font color=green>(âge, genre, pays d'origine, les sources de richesse, les secteurs d'activité)<font color=noir> et d'autres facteurs associés aux milliardaires, et identifier les tendances ou les patterns intéressants.
#
# <font color=red>**5.**<font color=green>Identifier les milliardaires les plus influents :<font color=noir> Identifier les milliardaires les plus riches ou les plus influents au fil du temps, examiner leurs parcours professionnels, leurs investissements, et leurs activités philanthropiques pour comprendre leur impact sur l'économie mondiale.
#
# <font color=red>**6.**<font color=green>Prédire les tendances futures :<font color=noir> Utiliser des techniques d'analyse prédictive pour extrapoler les tendances passées et identifier les possibles évolutions futures du nombre de milliardaires, de leur richesse totale, et de la répartition de cette richesse.

# %% [markdown]
# # **<font color=red>2)Prétraitement des donneés:💰 EDA + Cleaning**

# %% [markdown]
# # **A.Exploration des données:**

# %%
# Importation des librairies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Importation des données

sheet = pd.read_csv(r'C:\Users\USER\Desktop\archive(4)\all_billionaires_1997_2023.csv')

df=pd.DataFrame(sheet)

df.head()
# Out:
#    year  month  rank net_worth     last_name            first_name  \
# 0  1997      7   NaN     2.0 B  Sophonpanich                Chatri
# 1  1997      7   NaN     1.8 B     Adulyadej         King Bhumibol
# 2  1998      7   NaN     3.3 B         Safra                Edmond
# 3  1999      7   NaN     1.0 B       Hinduja  Srichand, Gopichand,
# 4  1999      7   NaN     7.1 B       Schwarz                Dieter
#
#                       full_name  birth_date   age gender  \
# 0  Chatri Sophonpanich & family  1934-02-28  73.0   Male
# 1       King Bhumibol Adulyadej  1927-12-05  69.0   Male
# 2                  Edmond Safra  1932-08-06  65.0   Male
# 3  Srichand & Gopichand Hinduja  1935-11-28   NaN    NaN
# 4                Dieter Schwarz  1939-09-24  59.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  NaN               NaN
# ...

# %%
df.tail()
# Out:
#        year  month    rank net_worth  last_name first_name  \
# 31727  2023      4  2540.0     1.0 B         Yu       Rong
# 31728  2023      4  2540.0     1.0 B  Yuengling    Richard
# 31729  2023      4  2540.0     1.0 B      Zhang    Gongyun
# 31730  2023      4  2540.0     1.0 B      Zhang    Guiping
# 31731  2023      4  2540.0     1.0 B      Zobel      Inigo
#
#                     full_name  birth_date   age gender country_of_citizenship  \
# 31727                 Yu Rong  1971-12-14  51.0   Male                  China
# 31728  Richard Yuengling, Jr.  1943-03-10  80.0   Male          United States
# 31729           Zhang Gongyun  1962-12-18  60.0   Male                  China
# 31730  Zhang Guiping & family  1951-08-21  71.0   Male                  China
# 31731             Inigo Zobel  1956-11-01  66.0   Male            Philippines
#
#       country_of_residence city_of_residence business_category  \
# 31727                China          Shanghai        Healthcare
# ...

# %%
df.shape
# Out:
# (31732, 19)

# %% [markdown]
# Mon dataset conteient <font color=red>19 colonnes et <font color=red>31732 lignes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31732 entries, 0 to 31731
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      31732 non-null  int64
#  1   month                     31732 non-null  int64
#  2   rank                      31714 non-null  float64
#  3   net_worth                 31732 non-null  object
#  4   last_name                 28043 non-null  object
#  5   first_name                27985 non-null  object
#  6   full_name                 31732 non-null  object
#  7   birth_date                27328 non-null  object
#  8   age                       31057 non-null  float64
#  9   gender                    27903 non-null  object
#  10  country_of_citizenship    31723 non-null  object
#  11  country_of_residence      31030 non-null  object
#  12  city_of_residence         30797 non-null  object
# ...

# %% [markdown]
# <font color=red>**Intérpretation:**
#
# <font color=green>**Les variables quantitatives** sont celles qui représentent des valeurs numériques et peuvent être mesurées ou comptées. Dans votre DataFrame, les variables quantitatives sont :
#
#  year (année) : une variable numérique représentant l'année.
#
#  month (mois) : une variable numérique représentant le mois.
#
#  rank (rang) : une variable numérique représentant le rang.
#
#  net_worth (fortune) : une variable numérique représentant la valeur nette.
#
# <font color=green>**Les variables qualitatives** sont celles qui représentent des catégories ou des groupes et ne peuvent pas être mesurées de manière numérique. Dans votre DataFrame, les variables qualitatives sont :
#
# last_name (nom de famille) : une variable catégorielle représentant le nom de famille.
#
# first_name (prénom) : une variable catégorielle représentant le prénom.
#
# full_name (nom complet) : une variable catégorielle représentant le nom complet.
#
# birth_date (date de naissance) : une variable catégorielle représentant la date de naissance.
#
# gender (genre) : une variable catégorielle représentant le genre.
#
# country_of_citizenship (pays de citoyenneté) : une variable catégorielle représentant le pays de citoyenneté.
#
# country_of_residence (pays de résidence) : une variable catégorielle représentant le pays de résidence.
#
# city_of_residence (ville de résidence) : une variable catégorielle représentant la ville de résidence.
#
# business_category (catégorie d'entreprise) : une variable catégorielle représentant la catégorie d'entreprise.
#
# business_industries (industries commerciales) : une variable catégorielle représentant les industries commerciales.
#
# organization_name (nom de l'organisation) : une variable catégorielle représentant le nom de l'organisation.
#
# position_in_organization (poste dans l'organisation) : une variable catégorielle représentant le poste dans l'organisation.
#
# self_made (auto-fabriqué) : une variable catégorielle représentant si la fortune a été auto-fabriquée.
#
# wealth_status (statut de richesse) : une variable catégorielle représentant le statut de richesse.

# %% [markdown]
# # **B.Nettoyage des données:**

# %%
# vérifier s'il existe des valeurs manquantes dans le dataset
df.isnull().sum()
# Out:
# year                            0
# month                           0
# rank                           18
# net_worth                       0
# last_name                    3689
# first_name                   3747
# full_name                       0
# birth_date                   4404
# age                           675
# gender                       3829
# country_of_citizenship          9
# country_of_residence          702
# city_of_residence             935
# business_category            5843
# business_industries           990
# organization_name           27344
# position_in_organization    27040
# self_made                    3689
# wealth_status                7146
# dtype: int64

# %%
#Déterminer les valeurs unique de l'attribut et le nombre de lignes y compris les valeurs NULLES
df['gender'].value_counts(dropna=False)
# Out:
# gender
# Male      24868
# NaN        3829
# Female     3035
# Name: count, dtype: int64

# %% [markdown]
# Il ya 3829 lignes qui conteint comme genre NaN

# %%
# Remplacement des valeurs NaN dans la colonne "gender"
# Définition d'une fonction pour déterminer le genre en fonction du nom
def determine_gender(row):
    if pd.isna(row['gender']):
        if row['full_name'] == "Bill Gates":
            return "Male"  # Si le nom complet est "Bill Gates", on met "Male"
    else:
        return row['gender']  # Si le genre est déjà défini, on le conserve

# Application de la fonction determine_gender pour remplacer les valeurs NaN dans la colonne "gender"
df['gender'] = df.apply(determine_gender, axis=1)

# %%
filtered_rows = df[df['full_name'] == "Bill Gates"]
print(filtered_rows)
# Out:
#        year  month  rank net_worth last_name first_name   full_name  \
# 19     2001      7   1.0    58.7 B     Gates    William  Bill Gates
# 354    2002      3   1.0    52.8 B     Gates    William  Bill Gates
# 687    2003      3   1.0    40.7 B     Gates    William  Bill Gates
# 1019   2004      3   1.0    46.6 B     Gates    William  Bill Gates
# 1451   2005      3   1.0    46.5 B     Gates    William  Bill Gates
# 1981   2006      3   1.0    50.0 B     Gates    William  Bill Gates
# 2609   2007      3   1.0    56.0 B     Gates    William  Bill Gates
# 3372   2008      3   3.0    58.0 B     Gates    William  Bill Gates
# 4278   2009      3   1.0    40.0 B     Gates    William  Bill Gates
# 5017   2010      3   2.0    53.0 B     Gates    William  Bill Gates
# 6028   2011      3   2.0    56.0 B     Gates       Bill  Bill Gates
# 7237   2012      3   2.0    61.0 B     Gates       Bill  Bill Gates
# 8463   2013      3   2.0    67.0 B     Gates       Bill  Bill Gates
# ...

# %%
#Suppression des lignes qui contiennent nulle dans la colonne Genre
df=df.dropna(subset=['gender'])
df.shape
# Out:
# (27903, 19)

# %%
#enléver B de net_woth et rendre le type float
df['net_worth'] = df['net_worth'].str.replace('B',"").astype(float)

# %%
df.head()
# Out:
#    year  month  rank  net_worth     last_name     first_name  \
# 0  1997      7   NaN        2.0  Sophonpanich         Chatri
# 1  1997      7   NaN        1.8     Adulyadej  King Bhumibol
# 2  1998      7   NaN        3.3         Safra         Edmond
# 4  1999      7   NaN        7.1       Schwarz         Dieter
# 5  1999      7   NaN        1.3  Ardila Lulle         Carlos
#
#                       full_name  birth_date   age gender  \
# 0  Chatri Sophonpanich & family  1934-02-28  73.0   Male
# 1       King Bhumibol Adulyadej  1927-12-05  69.0   Male
# 2                  Edmond Safra  1932-08-06  65.0   Male
# 4                Dieter Schwarz  1939-09-24  59.0   Male
# 5           Carlos Ardila Lülle  1930-06-04  68.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  NaN               NaN
# ...

# %%
# Liste des colonnes à supprimer
colonnes_inutiles = ['month','last_name','organization_name','country_of_citizenship','city_of_residence','business_industries']

# Supprimer les colonnes inutiles pour mon analyse
df = df.drop(columns=colonnes_inutiles)

# %%
# Pour les valeurs manquantes dans la colonne "first_name", il les remplace par le premier mot de la colonne "full_name"
df.loc[list(df.first_name.isnull().index),'first_name'] = df.loc[list(df.first_name.isnull().index),'full_name'].str.split().apply(lambda x:x[0])

# %%
# Convert birth_date to datetime (replace with your date format)
df['birth_date'] = pd.to_datetime(df['birth_date'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27903 entries, 0 to 31731
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      27903 non-null  int64
#  1   rank                      27887 non-null  float64
#  2   net_worth                 27903 non-null  float64
#  3   first_name                27903 non-null  object
#  4   full_name                 27903 non-null  object
#  5   birth_date                27255 non-null  datetime64[ns]
#  6   age                       27296 non-null  float64
#  7   gender                    27903 non-null  object
#  8   country_of_residence      27220 non-null  object
#  9   business_category         25767 non-null  object
#  10  position_in_organization  4672 non-null   object
#  11  self_made                 27903 non-null  object
#  12  wealth_status             24477 non-null  object
# ...

# %%
# Calculer la moyenne des âges
mean_age = df['age'].mean()

# Remplacer les valeurs nulles de la colonne "age" par la moyenne
df['age'].fillna(mean_age, inplace=True)

# %%
# Supprimer les lignes contenant des valeurs nulles dans la colonne "rank"
df.dropna(subset=['rank'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27887 entries, 18 to 31731
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      27887 non-null  int64
#  1   rank                      27887 non-null  float64
#  2   net_worth                 27887 non-null  float64
#  3   first_name                27887 non-null  object
#  4   full_name                 27887 non-null  object
#  5   birth_date                27240 non-null  datetime64[ns]
#  6   age                       27887 non-null  float64
#  7   gender                    27887 non-null  object
#  8   country_of_residence      27208 non-null  object
#  9   business_category         25757 non-null  object
#  10  position_in_organization  4671 non-null   object
#  11  self_made                 27887 non-null  object
#  12  wealth_status             24477 non-null  object
# ...

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF = df[df.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
duplicateRowsDF.shape
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# (1, 13)

# %%
#Supprimer les lignes Duppliquées
df=df.drop_duplicates()
df.shape
# Out:
# (27886, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27886 entries, 18 to 31731
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      27886 non-null  int64
#  1   rank                      27886 non-null  float64
#  2   net_worth                 27886 non-null  float64
#  3   first_name                27886 non-null  object
#  4   full_name                 27886 non-null  object
#  5   birth_date                27239 non-null  datetime64[ns]
#  6   age                       27886 non-null  float64
#  7   gender                    27886 non-null  object
#  8   country_of_residence      27207 non-null  object
#  9   business_category         25756 non-null  object
#  10  position_in_organization  4671 non-null   object
#  11  self_made                 27886 non-null  object
#  12  wealth_status             24476 non-null  object
# ...

# %%
# Créer le dictionnaire pour mapper les valeurs de genre
M_vs_F = {'Male': 0, 'Female': 1 , '1':0, '2':1 }

# Afficher les valeurs uniques dans la colonne 'gender'
print(df['gender'].unique())

# Remplacer les valeurs non définies dans le dictionnaire par une valeur par défaut (par exemple, -1)
df['gender'].fillna(-1, inplace=True)

# Utiliser le dictionnaire pour mapper la colonne 'gender' à la nouvelle colonne 'gender_0_1'
df['gender'] = df['gender'].map(M_vs_F)

# Convertir la colonne en type 'int64'
df['gender'] = df['gender'].astype('int64')

# Afficher les premières lignes pour vérification
df.head()
# Out:
# ['Male' 'Female']
#     year  rank  net_worth first_name          full_name birth_date   age  \
# 18  2000   0.0        1.4  Shigefumi     Shigefumi Wada 1952-08-30  47.0
# 19  2001   1.0       58.7       Bill         Bill Gates 1955-10-28  45.0
# 21  2001   3.0       30.4       Paul         Paul Allen 1953-01-21  48.0
# 30  2001  13.0       16.6      Steve      Steve Ballmer 1956-03-24  45.0
# 37  2001  21.0       11.7       Anne  Anne Cox Chambers 1919-12-01  81.0
#
#     gender country_of_residence business_category position_in_organization  \
# 18       0                Japan               NaN                      NaN
# 19       0        United States               NaN                      NaN
# 21       0        United States               NaN                      NaN
# 30       0        United States               NaN                      NaN
# 37       1        United States               NaN                      NaN
#
#    self_made wealth_status
# 18      True           NaN
# ...

# %%
# vérifier s'il existe des valeurs manquantes dans le dataset
df.isnull().sum()
# Out:
# year                            0
# rank                            0
# net_worth                       0
# first_name                      0
# full_name                       0
# birth_date                    647
# age                             0
# gender                          0
# country_of_residence          679
# business_category            2130
# position_in_organization    23215
# self_made                       0
# wealth_status                3410
# dtype: int64

# %%
#Déterminer les valeurs unique de l'attribut et le nombre de lignes y compris les valeurs NULLES
df['self_made'].value_counts(dropna=False)
# Out:
# self_made
# True     17529
# False    10357
# Name: count, dtype: int64

# %%
df['self_made'] = df['self_made'].replace({True: 1, False: 0})

# %% [markdown]
# # **C.Dummy variables:**

# %%
#Déterminer les valeurs unique de l'attribut et le nombre de lignes y compris les valeurs NULLES
df['wealth_status'].value_counts(dropna=False)
# Out:
# wealth_status
# Increased           12310
# Decreased            8397
# NaN                  3410
# Remained Even        2728
# Returned to List     1041
# Name: count, dtype: int64

# %%
# Use get_dummies to create dummy variables
dummy_df = pd.get_dummies(df['wealth_status'], prefix='wealth_status')

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, dummy_df], axis=1)

# Drop the original 'wealth_status' column
df.drop(columns=['wealth_status'], inplace=True)

# %%
# Assuming 'df' is your DataFrame
countryres_dummies = pd.get_dummies(df['country_of_residence'], prefix='country_of_residence')

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, countryres_dummies], axis=1)

# Drop the original 'country_of_residence' column
df.drop(columns=['country_of_residence'], inplace=True)

# %%
df.head()
# Out:
#     year  rank  net_worth first_name          full_name birth_date   age  \
# 18  2000   0.0        1.4  Shigefumi     Shigefumi Wada 1952-08-30  47.0
# 19  2001   1.0       58.7       Bill         Bill Gates 1955-10-28  45.0
# 21  2001   3.0       30.4       Paul         Paul Allen 1953-01-21  48.0
# 30  2001  13.0       16.6      Steve      Steve Ballmer 1956-03-24  45.0
# 37  2001  21.0       11.7       Anne  Anne Cox Chambers 1919-12-01  81.0
#
#     gender business_category position_in_organization  ...  \
# 18       0               NaN                      NaN  ...
# 19       0               NaN                      NaN  ...
# 21       0               NaN                      NaN  ...
# 30       0               NaN                      NaN  ...
# 37       1               NaN                      NaN  ...
#
#     country_of_residence_U.S. Virgin Islands  country_of_residence_Uganda  \
# 18                                     False                        False
# ...

# %%
#Déterminer les valeurs unique de l'attribut et le nombre de lignes y compris les valeurs NULLES
df['business_category'].value_counts(dropna=False)
# Out:
# business_category
# Technology                    2601
# Fashion & Retail              2408
# Manufacturing                 2381
# Real Estate                   2206
# NaN                           2130
# Diversified                   1947
# Finance and Investments       1747
# Healthcare                    1527
# Finance & Investments         1466
# Energy                        1183
# Food and Beverage             1131
# Service                        832
# Food & Beverage                800
# Media & Entertainment          776
# Metals & Mining                737
# Investments                    663
# Automotive                     592
# Construction & Engineering     541
# Logistics                      393
# Telecom                        342
# Sports                         321
# Media                          275
# Fashion and Retail             239
# Gambling & Casinos             238
# Health care                    104
# Finance                         93
# ...

# %%
# Assuming 'df' is your DataFrame
businesscategory_dummies = pd.get_dummies(df['business_category'], prefix='business_category')

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, businesscategory_dummies], axis=1)

# Drop the original 'country_of_residence' column
df.drop(columns=['business_category'], inplace=True)

# %%
# Assuming 'df' is your DataFrame
position_dummies = pd.get_dummies(df['position_in_organization'], prefix='position_in_organization')

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, position_dummies], axis=1)

# Drop the original 'country_of_residence' column
df.drop(columns=['position_in_organization'], inplace=True)

# %%
# Replace True/False with 0/1 for all boolean columns
df = df.applymap(lambda x: 1 if x == True else 0 if x == False else x)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1448\2625284325.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: 1 if x == True else 0 if x == False else x)

# %%
# afficher les statistiques descriptives pour données catégorielles avant d'effectuer les changements
df.describe(include=['float'])
# Out:
#                rank     net_worth           age
# count  27886.000000  27886.000000  27886.000000
# mean     980.665746      4.056044     63.418766
# std      646.052501      7.372083     13.479109
# min        0.000000      0.600000      0.000000
# 25%      442.000000      1.400000     54.000000
# 50%      894.000000      2.200000     63.417717
# 75%     1444.000000      3.900000     73.000000
# max     2674.000000    219.000000    101.000000

# %%
# afficher les statistiques descriptives pour données catégorielles avant d'effectuer les changements
df.describe(include=['object'])
# Out:
#        first_name              full_name
# count       27886                  27886
# unique       1956                   4818
# top          John  Christopher Goldsbury
# freq          534                     23

# %% [markdown]
# <font color=green>interpretation: apres limplementation des dummies variables , il reste 2 colonnes de types objets et 308 colonnes de type float

# %% [markdown]
# # **<font color=red>3)Analyse des données , visualisation et intérpretations:💰**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df.describe()
# Out:
#                year          rank     net_worth  \
# count  27886.000000  27886.000000  27886.000000
# mean    2017.118877    980.665746      4.056044
# min     2000.000000      0.000000      0.600000
# 25%     2014.000000    442.000000      1.400000
# 50%     2018.000000    894.000000      2.200000
# 75%     2021.000000   1444.000000      3.900000
# max     2023.000000   2674.000000    219.000000
# std        4.417608    646.052501      7.372083
#
#                           birth_date           age        gender  \
# count                          27239  27886.000000  27886.000000
# mean   1953-04-10 16:20:29.648665472     63.418766      0.108836
# min              1910-09-13 00:00:00      0.000000      0.000000
# 25%              1943-07-31 00:00:00     54.000000      0.000000
# 50%              1953-09-03 00:00:00     63.417717      0.000000
# 75%              1963-06-22 00:00:00     73.000000      0.000000
# max              2004-05-06 00:00:00    101.000000      1.000000
# ...

# %%
df.shape
# Out:
# (27886, 398)

# %%
df['gender'].value_counts().plot(
    kind = 'pie', 
    title = 'distribution des milliardaires par genre',
autopct='%1.1f%%');
plt.legend(labels=['Male', 'Female'])

# %% [markdown]
# <font color=green>interpretation: les hommes sont nettement plus nombreux que les femmes parmi les milliardaires dans votre ensemble de données
# cela peut etre du à :
# Historiquement, les hommes ont eu un accès plus large aux opportunités économiques, à l'éducation et aux réseaux d'affaires
# Dans certains secteurs et cultures d'entreprise, les femmes peuvent être sous-représentées aux postes de direction et de prise de décision, ce qui limite leur capacité à accumuler des richesses à grande échelle...
#
# <font color=red>=> unbalanced variable

# %%
df['self_made'].value_counts().plot(
    kind = 'pie', 
    title = 'self_made for billionnaires',
autopct='%1.1f%%');
plt.legend(labels=['true', 'false'])

# %% [markdown]
# <font color=green>interpretation: 63% des billionnaores ont devenus riches seules sans un soutient

# %%
df['wealth_status'].value_counts().plot(
    kind = 'pie', 
    title = 'self_made for billionnaires',
autopct='%1.1f%%');

# %% [markdown]
# <font color=green>interpretation: 50% des milliardaires leurs fortunes incrémente chaque année

# %%
#dataset.sort_values(by='net_worth',ascending=False,inplace=True)
ds = df.groupby('year').head(1)[['year','first_name','net_worth']].sort_values(by='year')
#df['net_worth'] = df['net_worth'].str.replace('B',"").astype(float)
fig= plt.figure(figsize=(20,5))
ax = sns.barplot(data=ds,x='year',y='net_worth',width=0.2)
ax.bar_label(ax.containers[0],ds['first_name'], fmt='%.1f')
plt.title(" Top 1 richest billionaires over the years ")
plt.show()

# %% [markdown]
# <font color=green>Interprétation: Ilya un changement remarquable dans les derniéres années , apparition des nouveaux top riches comme Elon musk et ca etait la valeur maximal de net_worth a traves les anneés . aussi, Bernard

# %% [markdown]
# # **A.correlation:**

# %%
# Coefficient de Pearson entre les variables 

stats.pearsonr(df['net_worth'], df['age'])
# Out:
# PearsonRResult(statistic=0.06218840880449644, pvalue=2.626568505097139e-25)

# %% [markdown]
# <font color=green>interpretation:Le coefficient de corrélation de Pearson entre la valeur nette (net worth) et l'âge est de 0,062, ce qui suggère une corrélation très faible entre ces deux variables. Cependant, la valeur p associée est extrêmement faible (2,63e-25), ce qui indique que cette corrélation observée est statistiquement significative malgré sa faiblesse. Cela suggère qu'il existe une relation positive très faible entre l'âge et la valeur nette : à mesure que l'âge augmente, la valeur nette a tendance à augmenter légèrement, mais cette relation est très faible

# %%
sns.lmplot(data = df, x='net_worth', y='age', line_kws={'color': 'red'})
plt.grid(True)
plt.title('age and net_worth correlation')
plt.show()

# %%
# Tracer le lmplot avec le DataFrame filtré
sns.lmplot(data=df, x='net_worth', y='age', hue='gender')
plt.grid(True)
plt.title('age and net_worth correlation by gender')
plt.show()

# %% [markdown]
# <font color=green>inetrpretation:Selon l'ensemble de données, le genre masculin (M) est deux fois plus riche dans la tranche d'âge de 80 ans que le genre féminin (F). Cependant, pour le genre féminin, il existe une corrélation plus forte entre l'âge et la valeur nette, ce qui signifie que le genre féminin s'enrichit plus rapidement.

# %%
df["age-Cat"] =df["age"].apply(lambda x: f"{int(x/10)*10} - {(int(x/10)*10)+10}" if x>0  else x)

# %%
df['age-Cat'] = df['age-Cat'].astype(str)
df['gender'] = df['gender'].astype(str)
#dataset["age-Cat"].value_counts().plot(kind='bar',rot=0)
fig= plt.figure(figsize=(20,5))
ax = sns.countplot(data=df.sort_values(by='age'),x='age-Cat',hue='gender',width=0.2)
plt.title("Range of Billionaires Age")
plt.show()

# %% [markdown]
# <font color=green>interprétation: les plus riches sont dans lintervalle [50,80] ans

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='age', y='net_worth', hue='gender', data=df, palette={'0': 'blue', '1': 'red'})

plt.title('Net Worth vs. Age')
plt.xlabel('Age')
plt.ylabel('Net Worth')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <font color=green>interpretation: Selon les données, les hommes jeunes ont généralement une valeur nette plus élevée, mais avec l'âge, les femmes âgées sont plus riches que les hommes âgés. C'est une statistique amusante et totalement nouvelle pour moi.

# %%
bill_df = df.sort_values('year', ascending=False).drop_duplicates('full_name')

top_categories = bill_df['business_category'].value_counts().head(5)
top_countries = bill_df['country_of_residence'].value_counts().head(5)
top_positions = bill_df['position_in_organization'].value_counts().head(5)

sns.set(style="whitegrid")


fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True)


sns.barplot(ax=axes[0], x=top_categories.values, y=top_categories.index, palette="viridis")
axes[0].set_title('Top 5 Business Categories')
axes[0].set_xlabel('Count')
axes[0].set_ylabel('Business Category')

sns.barplot(ax=axes[1], x=top_countries.values, y=top_countries.index, palette="viridis")
axes[1].set_title('Top 5 Business Countries')
axes[1].set_xlabel('Count')
axes[1].set_ylabel('Business Country')

sns.barplot(ax=axes[2], x=top_positions.values, y=top_positions.index, palette="viridis")
axes[2].set_title('Top 5 Business Positions')
axes[2].set_xlabel('Count')
axes[2].set_ylabel('Business Positions')

plt.tight_layout()

plt.show()

# %% [markdown]
# <font color=green>interpretation: les top categories business sont manufacturing et technologie et les top pays c'etait une surprise car la chine est avant les etats unis
# mais pour la positions dans le business c'etait presque la meme chose

# %%
# voir le taux de désabonnement en fonction des fonctionnalités des charges mensuells et des charges total
plt.figure(figsize=(12,4))

ax = sns.scatterplot(x='net_worth', y='age', hue='gender', data=df, palette = 'rocket')

plt.title(f'la distribution des millardaires en fonction de leurs richesse et leurs ages pour les males et les femelles')

for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.15, p.get_height()+0.03),fontsize=14)

plt.tight_layout()
plt.show()

# %%
# Distribution des âges selon la situation matrimoniale

plt.figure(figsize=(12, 4))

sns.boxplot(x = 'gender', y = 'year', data = df)

plt.xlabel('gender')

plt.ylabel('year')

plt.title('Distribution de la richesse durant les années par le genre')

plt.show()

# %% [markdown]
# <font color=green>interpretation: il n'ya pas une grandes différence en terme des années entre les 2 genres

# %%
import pandas as pd
import numpy as np

# Select only valid numeric columns
df_numeric = df.select_dtypes(include=['int64', 'float64'])
df_numeric = df_numeric.select_dtypes(exclude='object')

# Convert numeric columns to float (if conversion is necessary)
df_numeric = df_numeric.apply(lambda x: x.astype(np.float64) if x.dtype in ['int64', 'float64'] else x)

# Address 'genre' if applicable (e.g., one-hot encoding)
# ... (your code for handling 'genre')

# Calculate correlation matrix
corr_matrix = df_numeric.corr()

# Afficher la carte des corrélations (Display the correlation heatmap)
plt.figure(figsize=(16, 16))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, mask=mask, center=0, cmap='RdBu', linewidths=1, annot=True, fmt=".2f", vmin=-1, vmax=1)
plt.title('Carte des corrélations', fontsize=15, fontweight="bold")
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
df.dtypes
# Out:
# year                                       int64
# rank                                     float64
# net_worth                                float64
# first_name                                object
# full_name                                 object
# birth_date                        datetime64[ns]
# age                                      float64
# gender                                     int64
# country_of_citizenship                    object
# country_of_residence                      object
# business_category                         object
# position_in_organization                  object
# self_made                                  int64
# wealth_status_Decreased                     bool
# wealth_status_Increased                     bool
# wealth_status_Remained Even                 bool
# wealth_status_Returned to List              bool
# dtype: object

# %%
import pandas as pd
import numpy as np
import seaborn as sns  # Import Seaborn for heatmap

# Assuming 'df' is your DataFrame

# Select desired columns (excluding full_name and first_name)
cols_to_keep = [col for col in df.columns if col not in ['full_name', 'first_name','country_of_citizenship','country_of_residence', 'business_category','position_in_organization' ]]
df_selected = df[cols_to_keep]

# Calculate correlation matrix
corr_matrix = df_selected.corr()

# Create heatmap
sns.heatmap(corr_matrix).set_title('Carte des Coefficients de Pearson')
plt.show()

# %% [markdown]
# interpretation:

# %%
# Coefficient de Pearson entre les variables 

stats.pearsonr(df['net_worth'], df['age'])
# Out:
# PearsonRResult(statistic=0.06218840880449644, pvalue=2.626568505097139e-25)

# %% [markdown]
# <font color=green>interpretation:correlation faible  entre net_worth et age

# %%
stats.pearsonr(df['net_worth'], df['rank'])
# Out:
# PearsonRResult(statistic=-0.4250832347654433, pvalue=0.0)

# %% [markdown]
# <font color=green>interpretation: La corrélation de Pearson entre la valeur nette (net worth) et le rang est de -0,425, ce qui suggère une corrélation modérée à forte. De plus, la valeur p associée est très faible (0.0), ce qui indique que la corrélation observée est statistiquement significative. Cela suggère qu'il existe une relation inverse entre la valeur nette et le rang : plus le rang est élevé, plus la valeur nette est faible, et vice versa.

# %%
stats.pearsonr(df['net_worth'], df['year'])
# Out:
# PearsonRResult(statistic=0.04841233727398056, pvalue=6.025251010324445e-16)

# %% [markdown]
# <font color=green>interpretation: La corrélation de Pearson entre la valeur nette (net worth) et l'année est de 0,048, ce qui suggère une corrélation très faible. De plus, la valeur p associée est extrêmement faible (6.025251010324445e-16), indiquant que la corrélation observée est statistiquement significative

# %%
import pandas as pd

# Assuming df is your DataFrame

elon_musk_data = df[df['full_name'] == 'Elon Musk']  # Filter for Elon Musk's data

# %%
elon_musk_data = elon_musk_data.sort_values(by='year')  # Sort by 'years' column

# %%
import matplotlib.pyplot as plt

# Assuming elon_musk_data is the filtered DataFrame

plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.plot(elon_musk_data['year'], elon_musk_data['net_worth'])  # Plot 'net_worth' against 'years'
plt.xlabel('Years')
plt.ylabel('Net Worth')
plt.title('Evolution of Elon Musk\'s Net Worth')
plt.show()

# %% [markdown]
# <font color=green>interpretation: jai volu traiter le cas de Elon Musk tous seul car il a connu une augmentation significative au cours de derniéres années

# %%
import pandas as pd

# Assuming df is your DataFrame

bill_gates_data = df[df['full_name'] == 'Bill Gates']  # Filter for Bill Gates's data
bill_gates_data = bill_gates_data.sort_values(by='year')  # Sort by 'years' column
import matplotlib.pyplot as plt

# Assuming bill_gates_data is the filtered DataFrame

plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.plot(bill_gates_data['year'], bill_gates_data['net_worth'])  # Plot 'net_worth' against 'years'
plt.xlabel('Years')
plt.ylabel('Net Worth')
plt.title('Evolution of Bill Gates\'s Net Worth')
plt.show()

# %% [markdown]
# <font color=green>interpretation:meme chose pour Bill Gates

# %%
# voir l'impact du Churn sur les colonnes numériques
sns.pairplot(df, hue='gender', palette='rocket')
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # **B.FacetGrid:**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supposons que 'df' contient les colonnes 'gender', 'net_worth' et 'age' (Timestamp)
df['age_int'] = df['age'].dt.year  # Convertir 'age' en année

g = sns.FacetGrid(data=df, hue="age_int")  # Supprimer col="gender"
g.map(sns.barplot, "gender", "net_worth")  # Utiliser 'gender' et 'net_worth' pour les valeurs
g.add_legend()
g.set_titles("Valeur nette par sexe et tranche d'âge")  # Titre basé sur les colonnes
# Choisir une palette de couleurs (par défaut: "hls")
palette = "hls"  # Vous pouvez modifier la palette ici

# Définir la palette de couleurs pour chaque sous-graphique
for ax in g.axes:  # Utiliser g.axes pour obtenir les axes
    if isinstance(ax, np.ndarray):  # Vérifier le type d'objet
        continue  # Ignorer les tableaux d'axes
    ax.set_prop_cycle('color', palette)  # Appliquer la palette à chaque axe
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
num_accinfo_features = ['net_worth', 'year', 'age']  # Replace with actual feature names

# %%
# voir la concentration (taux) de désabonnement des clients selon fonctionnalités numérique relatives au compte 
plt.figure(figsize=(12,15))

for i,col in enumerate(num_accinfo_features):    
    plt.subplot(3,1,i + 1)    
    sns.kdeplot(df.loc[(df['gender'] == 0), col], label = 'femelle', shade = True)
    sns.kdeplot(df.loc[(df['gender'] == 1), col], label = 'male', shade = True)
    plt.title( col)
    plt.legend()
    plt.ylabel('Concentration du genre')
    plt.tight_layout()

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3584\2887599118.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[(df['gender'] == 0), col], label = 'femelle', shade = True)
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\AppData\Local\Temp\ipykernel_3584\2887599118.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[(df['gender'] == 1), col], label = 'male', shade = True)
# ...

# %% [markdown]
# # **C. les valeurs abérantes:**

# %%
# voir s'il existe des valeurs aberrantes
plt.figure(figsize=(12,15))

for i, col in enumerate(num_accinfo_features):
  plt.subplot(3,1,i + 1)
  ax = sns.boxplot(data=df, x=col, color='#BBD2E1')
  ax.set_xlabel(col)
  ax.set_ylabel(None)
  ax.set_title('Les valeurs aberrantes de la variable '+col)


plt.tight_layout()

plt.show()

# %% [markdown]
# # **E.une autre methode de correlation:**

# %%
# voir la corrélation entre la durée d'occupation et les charges total
plt.figure(figsize=(12,15))

ax = sns.lmplot(x='rank',y='net_worth', data=df, height=6, aspect=2)

plt.title(f'Correlation entre les variables rank et net_worth')

plt.tight_layout()
plt.show()

# %%
# voir la corrélation entre la durée d'occupation et les charges total
plt.figure(figsize=(12,15))

ax = sns.lmplot(x='year',y='net_worth', data=df, height=6, aspect=2)

plt.title(f'Correlation entre les variables year et net_worth')

plt.tight_layout()
plt.show()

# %%
# voir la corrélation entre la durée d'occupation et les charges total
plt.figure(figsize=(12,15))

ax = sns.lmplot(x='age',y='net_worth', data=df, height=6, aspect=2)

plt.title(f'Correlation entre les variables net_worth et age')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **B.Apprentissage non supervisé :Le clustering**

# %% [markdown]
# ## <font color='red'>1)Le clustering: Classsification Ascendante Hiérarchique</font>

# %%
df.head()
# Out:
#     year  rank  net_worth first_name          full_name birth_date   age  \
# 18  2000   0.0        1.4  Shigefumi     Shigefumi Wada 1952-08-30  47.0
# 19  2001   1.0       58.7       Bill         Bill Gates 1955-10-28  45.0
# 21  2001   3.0       30.4       Paul         Paul Allen 1953-01-21  48.0
# 30  2001  13.0       16.6      Steve      Steve Ballmer 1956-03-24  45.0
# 37  2001  21.0       11.7       Anne  Anne Cox Chambers 1919-12-01  81.0
#
#     gender country_of_residence business_category position_in_organization  \
# 18       0                Japan               NaN                      NaN
# 19       0        United States               NaN                      NaN
# 21       0        United States               NaN                      NaN
# 30       0        United States               NaN                      NaN
# 37       1        United States               NaN                      NaN
#
#     self_made wealth_status
# 18          1           NaN
# ...

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
cols_to_keep = [col for col in df.columns if col not in ['full_name', 'birth_date','first_name','country_of_citizenship','country_of_residence', 'business_category','position_in_organization' ,'wealth_status']]
df1= df[cols_to_keep]
Z3 = linkage(df1,method='ward',metric='euclidean')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27886 entries, 18 to 31731
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       27886 non-null  int64
#  1   rank       27886 non-null  float64
#  2   net_worth  27886 non-null  float64
#  3   age        27886 non-null  float64
#  4   gender     27886 non-null  int64
#  5   self_made  27886 non-null  int64
# dtypes: float64(3), int64(3)
# memory usage: 1.5 MB

# %%
plt.figure(figsize=(10,5))
plt.title('CAH avec matérialisation des classes')
dendrogram(Z3,labels=df1.index,orientation='top',color_threshold=2.94)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.title('CAH avec matérialisation des classes')
dendrogram(Z3,labels=df1.index,orientation='left',color_threshold=400)
plt.show()

# %% [markdown]
# # **C.Modélisation**

# %% [markdown]
# ## <font color='red'>1)Séparation des features et la target pour la modélisation</font>

# %%
import pandas as pd

# Group data by country_of_residence and calculate the maximum net worth for each group
grouped_data = df.groupby('country_of_residence')['net_worth'].max()

# %%
# Sort grouped data by maximum net worth (descending order)
top_5_countries = grouped_data.sort_values(ascending=False).head(5)

# %%
print("Top 5 Countries with Highest Maximum Net Worth:")
for country, max_worth in top_5_countries.items():
    print(f"{country}: {max_worth}")
# Out:
# Top 5 Countries with Highest Maximum Net Worth:
# United States: 219.0
# France: 211.0
# Mexico: 93.0
# India: 90.7
# Spain: 77.3

# %%
grouped_data = df.groupby('business_category')['net_worth'].max()

# %%
# Sort grouped data by maximum net worth (descending order)
top_5_industries = grouped_data.sort_values(ascending=False).head(5)

# %%
print("Top 5 business with Highest Maximum Net Worth:")
for business_category, max_worth in top_5_industries.items():
    print(f"{business_category}: {max_worth}")
# Out:
# Top 5 business with Highest Maximum Net Worth:
# Automotive: 219.0
# Fashion & Retail: 211.0
# Technology: 177.0
# Finance & Investments: 118.0
# Media & Entertainment: 94.5

# %%
grouped_data = df.groupby('position_in_organization')['net_worth'].max()

# %%
# Sort grouped data by maximum net worth (descending order)
top_5_positions = grouped_data.sort_values(ascending=False).head(5)

# %%
print("Top 5 positions with Highest Maximum Net Worth:")
for position_in_organization, max_worth in top_5_positions.items():
    print(f"{position_in_organization}: {max_worth}")
# Out:
# Top 5 positions with Highest Maximum Net Worth:
# CEO: 219.0
# Chairman and CEO: 211.0
# Entrepreneur: 177.0
# Chairman and Founder: 171.0
# CEO and Chairman: 151.0

# %%
import pandas as pd

# Assuming df is your DataFrame containing data on billionaires

# Sort DataFrame by net worth (descending order) and select top 20 (with duplicate names removed)
top_20_billionaires = df.sort_values(by='net_worth', ascending=False).head(50).drop_duplicates(subset='full_name', keep='first')

print("Top 20 Billionaires with Highest Net Worth (All Information):")

# Iterate through top 20 and print information for each
for index, row in top_20_billionaires.iterrows():
    print(f"\nBillionaire #{index+1}:")
    for col, value in row.items():
        print(f"{col}: {value}")
# Out:
# Top 20 Billionaires with Highest Net Worth (All Information):
#
# Billionaire #26425:
# year: 2022
# rank: 1.0
# net_worth: 219.0
# first_name: Elon
# full_name: Elon Musk
# birth_date: 1971-06-28 00:00:00
# age: 50.0
# gender: 0
# country_of_residence: United States
# business_category: Automotive
# position_in_organization: CEO
# self_made: 1
# wealth_status_Decreased: 0
# wealth_status_Increased: 1
# wealth_status_Remained Even: 0
# wealth_status_Returned to List: 0
#
# Billionaire #29093:
# year: 2023
# rank: 1.0
# net_worth: 211.0
# first_name: Bernard
# full_name: Bernard Arnault & family
# birth_date: 1949-03-05 00:00:00
# age: 74.0
# gender: 0
# country_of_residence: France
# business_category: Fashion & Retail
# position_in_organization: Chairman and CEO
# self_made: 0
# wealth_status_Decreased: 0
# wealth_status_Increased: 1
# wealth_status_Remained Even: 0
# wealth_status_Returned to List: 0
#
# Billionaire #23670:
# year: 2021
# rank: 1.0
# net_worth: 177.0
# ...

# %% [markdown]
#  ## <font color='red'>2)Les candidats features:

# %%
candidate_g_features = {
    'gender':[0], 'net_worth':[107.0], 'self_made':[1], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[1],
    'country_of_residence_France':[0], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[0],
    'position_in_organization_Entrepreneur':[0],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[0],
    'business_category_Automotive':[0], 'business_category_Fashion & Retail':[0],
    'business_category_Technology':[1], 'business_category_Finance & Investments':[0],
    'business_category_Media & Entertainment':[0]
    }

# %%
candidate_f_features = {
      'gender':[0], 'net_worth':[111.0], 'self_made':[1], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[1],
    'country_of_residence_France':[0], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[0],
    'position_in_organization_Entrepreneur':[0],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[0],
    'business_category_Automotive':[0], 'business_category_Fashion & Retail':[0],
    'business_category_Technology':[1], 'business_category_Finance & Investments':[0],
    'business_category_Media & Entertainment':[0]
    }

# %%
candidate_e_features = {'gender':[0], 'net_worth':[ 118.0], 'self_made':[1], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[1],
    'country_of_residence_France':[0], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[1],
    'position_in_organization_Entrepreneur':[0],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[0],
    'business_category_Automotive':[0], 'business_category_Fashion & Retail':[0],
    'business_category_Technology':[0], 'business_category_Finance & Investments':[1],
    'business_category_Media & Entertainment':[0]

    }

# %%
candidate_d_features = {'gender':[0], 'net_worth':[ 129.0], 'self_made':[1], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[1],
    'country_of_residence_France':[0], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[0],
    'position_in_organization_Entrepreneur':[0],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[0],
    'business_category_Automotive':[0], 'business_category_Fashion & Retail':[0],
    'business_category_Technology':[1], 'business_category_Finance & Investments':[0],
    'business_category_Media & Entertainment':[0]

    }

# %%
candidate_c_features = {'gender':[0], 'net_worth':[177.0], 'self_made':[1], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[1],
    'country_of_residence_France':[0], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[0],
    'position_in_organization_Entrepreneur':[1],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[0],
    'business_category_Automotive':[0], 'business_category_Fashion & Retail':[0],
    'business_category_Technology':[1], 'business_category_Finance & Investments':[0],
    'business_category_Media & Entertainment':[0]

    }

# %%
candidate_b_features = {'gender':[0], 'net_worth':[211.0], 'self_made':[0], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[0],
    'country_of_residence_France':[1], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[0],
    'position_in_organization_Entrepreneur':[0],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[1],
    'business_category_Automotive':[0], 'business_category_Fashion & Retail':[1],
    'business_category_Technology':[0], 'business_category_Finance & Investments':[0],
    'business_category_Media & Entertainment':[0]
   
   
    }

# %%
candidate_a_features = { 'gender':[0], 'net_worth':[219.0], 'self_made':[1], 'wealth_status_Decreased':[0],
    'wealth_status_Increased':[1], 'wealth_status_Remained Even':[0],
    'wealth_status_Returned to List':[0],
    'country_of_residence_United States':[1],
    'country_of_residence_France':[0], 'country_of_residence_India':[0],
    'country_of_residence_China':[0], 'country_of_residence_Mexico':[0],
    'country_of_residence_Spain':[0], 'position_in_organization_CEO':[1],
    'position_in_organization_Entrepreneur':[0],
    'position_in_organization_Chairman and Founder':[0],
    'position_in_organization_CEO and Chairman':[0],
    'position_in_organization_chairman and CEO':[0],
    'business_category_Automotive':[1], 'business_category_Fashion & Retail':[0],
    'business_category_Technology':[0], 'business_category_Finance & Investments':[0],
    'business_category_Media & Entertainment':[0]
}

# %%
df.describe(include=['int'])
# Out:
#                year        gender     self_made  wealth_status_Decreased  \
# count  27886.000000  27886.000000  27886.000000             27886.000000
# mean    2017.118877      0.108836      0.628595                 0.301119
# std        4.417608      0.311439      0.483189                 0.458752
# min     2000.000000      0.000000      0.000000                 0.000000
# 25%     2014.000000      0.000000      0.000000                 0.000000
# 50%     2018.000000      0.000000      1.000000                 0.000000
# 75%     2021.000000      0.000000      1.000000                 1.000000
# max     2023.000000      1.000000      1.000000                 1.000000
#
#        wealth_status_Increased  wealth_status_Remained Even  \
# count             27886.000000                 27886.000000
# mean                  0.441440                     0.097827
# std                   0.496568                     0.297086
# min                   0.000000                     0.000000
# ...

# %% [markdown]
# ## <font color='red'> 3) Les modéles:

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import precision_score, accuracy_score, recall_score


# Assuming df is your DataFrame containing billionaire data

# **Check column names in your DataFrame and update accordingly**
X = df[[  # Replace with actual feature names from your DataFrame columns
    'gender','net_worth', 'self_made', 'wealth_status_Decreased',
    'wealth_status_Increased', 'wealth_status_Remained Even', 
    'wealth_status_Returned to List', 
    'country_of_residence_United States', 
    'country_of_residence_France', 'country_of_residence_India',
    'country_of_residence_China', 'country_of_residence_Mexico',
    'country_of_residence_Spain', 'position_in_organization_CEO',
    'position_in_organization_Entrepreneur',
    'position_in_organization_Chairman and Founder',
    'position_in_organization_CEO and Chairman', 
    'position_in_organization_chairman and CEO',
    'business_category_Automotive', 'business_category_Fashion & Retail', 
    'business_category_Technology', 'business_category_Finance & Investments',
    'business_category_Media & Entertainment'
]]


# Target variable (current net worth)
y = df['net_worth']  # Assuming you have a 'net_worth' column

# Train the model
model = LinearRegression()
model.fit(X, y)

# Predict net worth for all billionaires in df
predictions = model.predict(X.values.tolist())  # Use all features from df

# Create DataFrame with billionaire names and predicted net worth
sorted_billionaires = pd.DataFrame({'billionaire': df['full_name'], 'predicted_net_worth': predictions})

# Sort billionaires by predicted net worth (highest first)
sorted_billionaires = sorted_billionaires.sort_values(by='predicted_net_worth', ascending=False)

# Top predicted billionaire
top_billionaire = sorted_billionaires.iloc[0]['billionaire']
print(f"Top predicted billionaire with highest net worth: {top_billionaire}")
# Out:
# Top predicted billionaire with highest net worth: Elon Musk
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score  # Using R-squared for regression

# Assuming df is your DataFrame containing billionaire data
# **Check column names in your DataFrame and update accordingly**
X = df[[
    'age', 'gender', 'net_worth', 'self_made', 'wealth_status_Decreased',
    'wealth_status_Increased', 'wealth_status_Remained Even',
    'wealth_status_Returned to List',
    'country_of_residence_United States',
    'country_of_residence_France', 'country_of_residence_India',
    'country_of_residence_China', 'country_of_residence_Mexico',
    'country_of_residence_Spain', 'position_in_organization_CEO',
    'position_in_organization_Entrepreneur',
    'position_in_organization_Chairman and Founder',
    'position_in_organization_CEO and Chairman',
    'position_in_organization_chairman and CEO',
    'business_category_Automotive', 'business_category_Fashion & Retail',
    'business_category_Technology', 'business_category_Finance & Investments',
    'business_category_Media & Entertainment'
]]


# Target variable (current net worth)
y = df['net_worth']  # Assuming you have a 'net_worth' column

# Train the model
model = LinearRegression()
model.fit(X, y)

# Make predictions
predictions = model.predict(X.values.tolist())  # Use all features from df

# R-squared score (measure of regression performance)
r2 = r2_score(y, predictions)

# Print R-squared score
print(f"R-squared: {r2:.3f}")

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate regression metrics
mae = mean_absolute_error(y, predictions)
mse = mean_squared_error(y, predictions)
r2 = r2_score(y, predictions)

print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"Mean Squared Error (MSE): {mse:.3f}")
print(f"R-squared (R2) Score: {r2:.3f}")
# Out:
# R-squared: 1.000
# Mean Absolute Error (MAE): 0.000
# Mean Squared Error (MSE): 0.000
# R-squared (R2) Score: 1.000
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error


# Sélection des caractéristiques pertinentes
features =[
     'gender', 'net_worth', 'self_made', 'wealth_status_Decreased',
    'wealth_status_Increased', 'wealth_status_Remained Even',
    'wealth_status_Returned to List',
    'country_of_residence_United States',
    'country_of_residence_France', 'country_of_residence_India',
    'country_of_residence_China', 'country_of_residence_Mexico',
    'country_of_residence_Spain', 'position_in_organization_CEO',
    'position_in_organization_Entrepreneur',
    'position_in_organization_Chairman and Founder',
    'position_in_organization_CEO and Chairman',
    'position_in_organization_chairman and CEO',
    'business_category_Automotive', 'business_category_Fashion & Retail',
    'business_category_Technology', 'business_category_Finance & Investments',
    'business_category_Media & Entertainment'
]

# Suppression des lignes avec des valeurs manquantes dans les caractéristiques ou la cible
df.dropna(subset=features+['net_worth'], inplace=True)

# Séparation des données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(df[features], df['net_worth'], test_size=0.2, random_state=42)

# Entraînement du modèle de régression
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Prédiction sur l'ensemble de test
predictions = model.predict(X_test)

# Évaluation du modèle
mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error: {mse}")


candidate_a_data = pd.DataFrame(candidate_a_features)
candidate_b_data = pd.DataFrame(candidate_a_features)
candidate_c_data = pd.DataFrame(candidate_a_features)
candidate_d_data = pd.DataFrame(candidate_a_features)
candidate_e_data = pd.DataFrame(candidate_a_features)
candidate_f_data = pd.DataFrame(candidate_a_features)
candidate_g_data = pd.DataFrame(candidate_a_features)

# Concatenate the dataframes
future_data = pd.concat([candidate_a_data, candidate_b_data, candidate_c_data,
                         candidate_d_data, candidate_e_data, candidate_f_data, candidate_g_data], axis=0, ignore_index=True)


future_predictions = model.predict(future_data)
top_billionaire_index = future_predictions.argmax()
top_billionaire = future_data.iloc[top_billionaire_index]

print("Top 1 Billionaire in the Future:")
print(top_billionaire)
# Out:
# Mean Squared Error: 0.034722261339189674
# Top 1 Billionaire in the Future:
# gender                                             0.0
# net_worth                                        219.0
# self_made                                          1.0
# wealth_status_Decreased                            0.0
# wealth_status_Increased                            1.0
# wealth_status_Remained Even                        0.0
# wealth_status_Returned to List                     0.0
# country_of_residence_United States                 1.0
# country_of_residence_France                        0.0
# country_of_residence_India                         0.0
# country_of_residence_China                         0.0
# country_of_residence_Mexico                        0.0
# country_of_residence_Spain                         0.0
# position_in_organization_CEO                       1.0
# position_in_organization_Entrepreneur              0.0
# position_in_organization_Chairman and Founder      0.0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error


# Sélectionner les caractéristiques pertinentes et la cible
features = ['gender', 'net_worth', 'self_made', 'wealth_status_Decreased',
            'wealth_status_Increased', 'wealth_status_Remained Even',
            'wealth_status_Returned to List',
            'country_of_residence_United States',
            'country_of_residence_France', 'country_of_residence_India',
            'country_of_residence_China', 'country_of_residence_Mexico',
            'country_of_residence_Spain', 'position_in_organization_CEO',
            'position_in_organization_Entrepreneur',
            'position_in_organization_Chairman and Founder',
            'position_in_organization_CEO and Chairman',
            'position_in_organization_chairman and CEO',
            'business_category_Automotive', 'business_category_Fashion & Retail',
            'business_category_Technology', 'business_category_Finance & Investments',
            'business_category_Media & Entertainment']
target = 'net_worth'

# Séparation des données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Entraînement du modèle de régression
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Prédiction sur l'ensemble de test
predictions = model.predict(X_test)

# Évaluation du modèle
mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error: {mse}")

# Interprétation des prédictions
# Sélectionnez un exemple de données de test pour l'analyse
example_index = 0
example_data = X_test.iloc[example_index]
true_value = y_test.iloc[example_index]
predicted_value = predictions[example_index]

print("Exemple de données de test:")
print(example_data)
print(f"Valeur réelle: {true_value}")
print(f"Valeur prédite: {predicted_value}")

# Analyse de l'importance des caractéristiques
feature_importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Importance des caractéristiques:")
print(sorted_feature_importance_df)
# Out:
# Mean Squared Error: 0.034722261339189674
# Exemple de données de test:
# gender                                           0.0
# net_worth                                        2.2
# self_made                                        0.0
# wealth_status_Decreased                          0.0
# wealth_status_Increased                          1.0
# wealth_status_Remained Even                      0.0
# wealth_status_Returned to List                   0.0
# country_of_residence_United States               0.0
# country_of_residence_France                      0.0
# country_of_residence_India                       1.0
# country_of_residence_China                       0.0
# country_of_residence_Mexico                      0.0
# country_of_residence_Spain                       0.0
# position_in_organization_CEO                     0.0
# position_in_organization_Entrepreneur            0.0
# position_in_organization_Chairman and Founder    0.0
# ...

# %%
from sklearn.metrics import mean_absolute_error, r2_score
# Calcul des métriques
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

# Affichage des métriques
print('-'*10 + model.__class__.__name__ + '-'*10)
print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
print('R-squared:', r2)
print('Accuracy:', model.score(X_train, y_train))
# Out:
# ----------RandomForestRegressor----------
# Mean Squared Error: 0.034722261339189674
# Mean Absolute Error: 0.004546342775192233
# R-squared: 0.9992767941953674
# Accuracy: 0.9995884674111636

# %% [markdown]
# Dans notre cas, les valeurs de MSE et MAE sont très faibles, ce qui suggère que notre modèle RandomForestRegressor s'ajuste bien aux données de test. De plus, un R-squared proche de 1 (0.999) indique que notre modèle explique très bien la variance des données, ce qui est une excellente performance pour un modèle de régression.
# notre modèle RandomForestRegressor semble avoir une très bonne performance sur l'ensemble de test, avec des erreurs très faibles et une capacité élevée à expliquer la variance des données.

# %% [markdown]
# ## <font color='red'>Interprétation:
# Mean Squared Error (MSE) : Cette métrique mesure en moyenne la différence quadratique entre les valeurs prédites par le modèle et les valeurs réelles. Dans votre cas, le MSE est de 0.0347. Cela signifie que, en moyenne, les prédictions de votre modèle diffèrent des valeurs réelles de 0.0347 unités au carré. Étant donné que le MSE est une mesure quadratique, il est difficile de l'interpréter directement en unités de la variable cible, mais une valeur plus basse indique généralement de meilleures performances.
# Mean Absolute Error (MAE) : Cette métrique mesure en moyenne la différence absolue entre les valeurs prédites par le modèle et les valeurs réelles. Dans votre cas, le MAE est de 0.0045. Cela signifie que, en moyenne, les prédictions de votre modèle diffèrent des valeurs réelles de 0.0045 unités. Comme pour le MSE, une valeur plus basse indique de meilleures performances.
# R-squared (Coefficient de détermination) : Ce coefficient mesure la proportion de la variance de la variable dépendante (net_worth) qui est expliquée par le modèle. Dans votre cas, le R-squared est de 0.9993, ce qui est très proche de 1. Cela signifie que près de 99.93% de la variance de la variable net_worth est expliquée par votre modèle. En d'autres termes, votre modèle capture presque toute la variabilité des données, ce qui est un signe de bonne performance.
# En résumé, vos métriques montrent que votre modèle RandomForestRegressor fonctionne très bien pour prédire la valeur nette des individus dans votre ensemble de données, avec des erreurs très faibles et une capacité élevée à expliquer la variance des données. Cela suggère que votre modèle est bien ajusté aux données et qu'il peut être utilisé avec confiance pour faire des prédictions sur de nouvelles données.

# %% [markdown]
# # **<font color=red>4)Conclusion:💰**

# %% [markdown]
# En se basant sur les analyses effectuées, on peut tirer les conclusions suivantes :
#
# 1. Forte concentration de la richesse :
#
#     Un nombre restreint de milliardaires détient une part importante de la richesse mondiale, ce qui met en évidence les inégalités croissantes.
#     La fortune nette des milliardaires a considérablement augmenté au cours des dernières années, tandis que les revenus des classes moyennes et inférieures stagnent ou diminuent.
#
# 2. Facteurs contributifs :
#
#     La mondialisation, les progrès technologiques et les politiques fiscales favorables aux plus riches ont contribué à l'accumulation de richesses chez les milliardaires.
#     Des facteurs tels que les héritages, les investissements spéculatifs et les pratiques monopolistiques peuvent également jouer un rôle.
#
# 3. Conséquences potentielles :
#
#     L'accumulation de richesses chez les milliardaires peut exacerber les inégalités sociales et économiques, entraînant des troubles sociaux et une instabilité politique.
#     Cela peut également avoir un impact négatif sur la démocratie, la cohésion sociale et la mobilité sociale.
#
# 4. Recommandations possibles :
#
#     Mettre en place des politiques fiscales progressives pour redistribuer les richesses et réduire les inégalités.
#     Renforcer les réglementations anti-monopoles et promouvoir une concurrence équitable.
#     Investir dans l'éducation, la santé et d'autres programmes sociaux pour améliorer les opportunités pour tous.
#     Encourager la transparence et la responsabilité des entreprises et des milliardaires.
#
# 5. Points importants à considerer :
#
#     Il est important de continuer à analyser les données sur les milliardaires et de comprendre les facteurs qui contribuent à leur richesse.
#     Il est nécessaire d'avoir un débat public ouvert et éclairé sur les inégalités et les moyens de les réduire.
#     Des solutions politiques et sociales efficaces doivent être élaborées et mises en œuvre pour garantir une répartition plus équitable de la richesse et des opportunités.
#
# En conclusion, l'analyse du dataset des milliardaires met en évidence des inégalités croissantes et soulève des questions importantes sur la concentration de la richesse et ses impacts sur la société. Il est crucial de poursuivre les recherches et les discussions sur ce sujet afin de promouvoir une société plus juste et équitable.

# %% [markdown]
# # **<center> <font color=green>💰FIN 💰**
